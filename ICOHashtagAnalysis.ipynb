# %%
#This program processes the tweets scraped from the twitter search results for nine ICO campaigns, and gets all the hashtags 
#available in these tweets.
#The tweets to be processed are available in file "Tweet_Text" generated by program "icoTweetScrape.ipynb".
#The results are stored in a file named "hashtag_counts.csv" and holds the hashtags, and the corresponding counts for each

# %%
import pandas as pd
import re #regex
from collections import Counter
import csv

# %%
tweetTextdf = pd.read_csv("Tweet_Text.csv")
tweetTextdf.head()
# Out:
#    Unnamed: 0    ico                                              tweet
# 0           0  tezos  b'Did you participated in Tezos? Already locke...
# 1           1  tezos  b'#Ethereum Co-Founder Takes to Twitter to Dis...
# 2           2  tezos  b'Will this drive the XRP value up? #cryptocur...
# 3           3  tezos  b'@CamiRusso and I just met with the CEO of @R...
# 4           4  tezos  b"Check out my latest Flux episode- on bitcoin...

# %%
hashtagList = []

#Iterate through each tweet and grab the hashtags
for index, row in tweetTextdf.iterrows():
    #print( re.findall(r"#(\w+)", row["tweet"]))
    hashtags =  re.findall(r"#(\w+)", row["tweet"])
    
    #if the hastags list returned from above is not empty, add each individual hashtg to the list of previously accumulated 
    #hashtags
    if hashtags:
        for hashtag in hashtags:
            hashtagList.append( hashtag)

print(hashtagList)
# Out:
# ['Ethereum', 'Tezos', 'Blockchain', 'cryptocurrency', 'ripple', 'xrp', 'bitcoin', 'btc', 'blockchain', 'ethereum', 'ICO', 'litecoin', 'tezos', 'kik', 'KIN', 'xrp', 'btc', 'bitcoin', 'ethereum', 'crypto', 'blockchain', 'eth', 'cryptocurrency', 'ico', 'tezos', 'tezos', 'Tezos', 'blockchain', 'ico', 'cryptocurrency', 'steem', 'blockchain', 'cryptocurrency', 'monaco', 'encrypgen', 'eos', 'bat', 'tenX', 'suncontract', 'tezos', 'bitcoin', 'Tezos', 'tezos', 'Tezos', 'cryptocurrency', 'steem', 'blockchain', 'Tezos', 'tezos', 'tezos', 'ICO', 'insurex', 'tezos', 'wtt', 'EHT', 'XRP', 'bit', 'TEZOS', 'EdwardsPumps', 'Ethereum', 'Blockchain', 'Crypto', 'cryptocurrency', 'Bitcoin', 'Tezos', 'qbSlgccvIgOg', 'Tezos', 'TOA17', 'Tezos', 'Bitcoin', 'Jawbone', 'ico', 'ethereum', 'bitcoin', 'tezos', 'cryptocurrency', 'steem', 'blockchain', 'ETH', 'XTZ', 'BTC', 'BloodBath', 'ICO', 'blockchain', 'fintech', 'finance', 'crowfunding', 'btcnews', 'blockchain', 'Ethereum', 'Twitter', 'Blockchain', 'fintech', 'TEZOS', 'TEZOS', 'tezos', 'EOS', 'NEO', 'antshares', 'Qtum', 'Tauchain', 'Bitcoin', 'tezos', 'Ethereum', 'Tezos', 'Blockchain', 'tezos', 'tezos', 'blockchain', 'cryptovalley', 'blockchain', 'ICO', 'QTUM', 'Cosmos', 'BAT', 'Bancor', 'Status', 'TenX', 'Tezos', 'EOS', 'news', 'bitcoin', 'crypto', 'bitcoin', 'crypto', 'news', 'fintech', 'AI', 'ethereum', 'bitcoin', 'tezos', 'ICOs', 'Tezos', 'Fintech', 'Podcast', 'Tezos', 'tezos', 'crowdfunding', 'ICO', 'Tezos', 'cryptocurrency', 'bitcoin', 'ethereum', 'tezos', 'cryptocurrency', 'ethereum', 'bitcoin', 'blockchain', 'tezos', 'Tezos', 'ICO', 'Cryptocurrencies', 'Blockchain', 'tezos', 'blockchain', 'blockchain', 'ICO', 'Tezos', 'Ethereum', 'ICO', 'Ethereum', 'Ether', 'EOS', 'Tezos', 'cryptocurrency', 'steem', 'blockchain', 'cryptocurrency', 'steem', 'blockchain', 'ICO', 'Tezos', 'cryptocurrency', 'steem', 'blockchain', 'ETH', 'Ethereum', 'ethereum', 'ico', 'tezos', 'eos', 'TEZOS', 'tezos', 'tezos', 'cryptocurrency', 'Tezos', 'Cryptocurrencies', 'Cryptocurrency', 'Blockchain', 'experiment', 'Tezos', 'Crypto', 'Investing', 'Tothemoon', 'cryptocurrency', 'steem', 'blockchain', 'Tezos', 'bitcoin', 'blockchain', 'cryptocurrency', 'btc', 'tezos', 'status', 'eos', 'tezos', 'spamos', 'ripoffos', 'Tezos', 'Blockchain', 'Tezos', 'CryptoFunding', 'tez0s', 'tezos', 'burnyourbtc', 'tezos', 'bitcoin', 'Bitcoin', 'Blockchain', 'ICOs', 'Bancor', 'Tezos', 'Blockchain', 'bitcoin', 'Crypto', 'Pump', 'tezos', 'tezos', 'ico', 'bitcoin', 'ethereum', 'Tezos', 'ICO', 'cryptocurrency', 'steem', 'blockchain', 'Tezos', 'bitcoin', 'ethereum', 'tezos', 'blockchain', 'singularity', 'futurism', 'ico', 'blockchain', 'Bravery', 'tezos', 'Tezos', 'blockchain', 'supplychain', 'tezos', 'balajiballer', 'Tezos', 'Tezos', '3wmJNO7BzgOt', 'Tezos', 'ICO', 'tezos', 'bancor', 'basicattentiontoken', 'status', 'ICO', 'tezos', 'bancor', 'basicattentiontoken', 'status', 'Tezos', 'Tezos', 'cryptocurrency', 'steem', 'blockchain', 'tezos', 'tezos', 'crowdfunding', 'startup', 'Tezos', 'ICO', 'CRYPTO', 'blockchain', 'tezos', 'Tezos', 'startups', 'CryptoCurrency', 'ICO', 'Tezos', 'blockchain', 'medium', 'bitcoin', 'cryptocurrency', 'steem', 'blockchain', 'tezos', 'tezos', 'tezzies', 'Tezos', 'cryptocurrency', 'steem', 'blockchain', 'ICO', 'blockchain', 'cryptocurrency', 'steem', 'blockchain', 'blockchain', 'Tezos', 'crypto', 'bottom', 'Tezos', 'XTZ', 'blockchain', 'BTC', 'bitcoin', 'ethereum', 'ETH', 'ICO', 'blockchain', 'Tezos', 'ICO', 'Tezos', 'ICO', 'Tezos', 'cryptocurrency', 'steem', 'blockchain', 'blockchain', 'ico', 'blockchain', 'cryptocurrency', 'crowdfund', 'ICO', 'funding', 'blockchain', 'tezos', 'bitcoin', 'Tezos', 'ICO', 'tezos', 'ico', 'blockchain', 'blockchain', 'Tezos', 'crowdfund', 'ICO', 'cryptocurrency', 'tezos', 'xtz', 'bitcoin', 'btc', 'Blockchain', 'ICO', 'blockchain', 'dealbox', 'ico', 'cryptocurrency', 'steem', 'b', 'tezos', 'ico', 'bitcoin', 'ETHEREUM', 'tezos', 'Cyrptocurrency', 'Altcoins', 'Forex', 'Currenct', 'XRP', 'BTC', 'ETC', 't ...

# %%
#Calculate the frequency of each hashtag to find th most popular ones
hashtagCounterDict = Counter(hashtagList)
# Out:
# dict_items([('Ethereum', 68), ('Tezos', 156), ('Blockchain', 77), ('cryptocurrency', 224), ('ripple', 2), ('xrp', 3), ('bitcoin', 260), ('btc', 31), ('blockchain', 449), ('ethereum', 135), ('ICO', 306), ('litecoin', 1), ('tezos', 182), ('kik', 1), ('KIN', 1), ('crypto', 48), ('eth', 16), ('ico', 126), ('steem', 84), ('monaco', 1), ('encrypgen', 1), ('eos', 6), ('bat', 1), ('tenX', 1), ('suncontract', 1), ('insurex', 1), ('wtt', 1), ('EHT', 1), ('XRP', 7), ('bit', 1), ('TEZOS', 13), ('EdwardsPumps', 1), ('Crypto', 23), ('Bitcoin', 82), ('qbSlgccvIgOg', 1), ('TOA17', 1), ('Jawbone', 1), ('ETH', 40), ('XTZ', 5), ('BTC', 18), ('BloodBath', 1), ('fintech', 82), ('finance', 14), ('crowfunding', 1), ('btcnews', 1), ('Twitter', 1), ('EOS', 6), ('NEO', 1), ('antshares', 1), ('Qtum', 1), ('Tauchain', 2), ('cryptovalley', 1), ('QTUM', 1), ('Cosmos', 1), ('BAT', 2), ('Bancor', 225), ('Status', 5), ('TenX', 2), ('news', 24), ('AI', 3), ('ICOs', 11), ('Fintech', 7), ('Podcast', 1), ('crowdfunding', 12), ('Cryptocurrencies', 5), ('Ether', 3), ('Cryptocurrency', 12), ('experiment', 1), ('Investing', 1), ('Tothemoon', 1), ('status', 8), ('spamos', 1), ('ripoffos', 1), ('CryptoFunding', 1), ('tez0s', 2), ('burnyourbtc', 1), ('Pump', 4), ('singularity', 1), ('futurism', 3), ('Bravery', 1), ('supplychain', 10), ('balajiballer', 1), ('3wmJNO7BzgOt', 1), ('bancor', 99), ('basicattentiontoken', 2), ('startup', 20), ('CRYPTO', 1), ('startups', 4), ('CryptoCurrency', 4), ('medium', 36), ('tezzies', 5), ('bottom', 1), ('crowdfund', 23), ('funding', 4), ('xtz', 2), ('dealbox', 1), ('b', 1), ('ETHEREUM', 7), ('Cyrptocurrency', 1), ('Altcoins', 4), ('Forex', 1), ('Currenct', 1), ('ETC', 2), ('REC', 1), ('STR', 1), ('NXT', 2), ('DASH', 1), ('BITCOIN', 3), ('BLOCKCHAIN', 2), ('RIPPLE', 1), ('DesafioSuperHumanos', 1), ('parkour', 1), ('Cafeteros', 1), ('paisas', 1), ('trading', 6), ('speculating', 5), ('Vox', 1), ('Xvg', 1), ('Dgb', 1), ('Eth', 5), ('Starta', 1), ('strat', 1), ('stratis', 3), ('santiment', 1), ('crowdfunded', 1), ('myflower', 1), ('CryptoWorld', 1), ('StrongLeadership', 1), ('Yn1', 1), ('xOFYxTOXXZqA', 1), ('tech', 18), ('smallbiz', 1), ('digital', 5), ('commonwealth', 1), ('fundraiser', 1), ('followthemoney', 4), ('Ledger', 1), ('CryptoTrading', 12), ('fact', 2), ('crowdfundinfg', 1), ('tokensale', 3), ('300Token', 1), ('nextbigthing', 1), ('scams', 1), ('tezosico', 4), ('altcoin', 10), ('altcoins', 4), ('News', 13), ('ContraTheHerd', 1), ('Steemit', 4), ('cryptocurrencies', 7), ('BitcoinIsTheFuture', 1), ('rialto', 1), ('473963', 1), ('474022', 1), ('cryptocu', 1), ('crowdsale', 29), ('alts', 1), ('hype', 1), ('tz1', 2), ('PUMP', 1), ('smartcontracts', 4), ('opreturn', 1), ('justsaying', 1), ('pump', 1), ('crypro', 1), ('AntShares', 1), ('minimum', 1), ('Business', 3), ('Arthur', 1), ('bitcoins', 1), ('ThaDogeHouse', 1), ('475622', 1), ('Baseball', 1), ('code', 4), ('IC', 1), ('VC', 7), ('JOMO', 1), ('ConspiracyTheory', 1), ('bloc', 1), ('futures', 1), ('stackexchange', 2), ('scam', 7), ('dash', 2), ('Zcash', 1), ('c', 1), ('Litecoin', 2), ('s', 1), ('foll', 1), ('Slack', 1), ('slackbot', 1), ('Beyonc', 4), ('TZ1', 1), ('stee', 1), ('token', 24), ('xbt', 1), ('segwit2x', 2), ('chinesemob', 1), ('ether', 7), ('p69206', 1), ('slack', 2), ('fun', 1), ('HuffingtonPost', 1), ('pdf', 1), ('Tezzies', 1), ('Btc', 1), ('cppethereum', 1), ('SCAM', 2), ('tez', 1), ('contribution', 3), ('p69099', 1), ('XMR', 1), ('Monero', 1), ('Altcoin', 10), ('Reddit', 2), ('Betting', 1), ('etherium', 2), ('ste', 3), ('regulation', 1), ('uscitizens', 1), ('prohibited', 1), ('facts', 1), ('CoinFundraiser', 1), ('MaidSafe', 1), ('Golem', 1), ('excited', 1), ('DLT', 1), ('Web3', 1), ('technology', 8), ('angellist', 1), ('Bitcache', 1), ('Filecoin', 66), ('SEC', 4), ('FileCoin', 40), ('Finance', 4), ('1', 7), ('balance', 1), ('investors', 2), ('venture', 9), ('BCAP', 1), ('Civic', 2), ('CVC', 1), ('filecoin', 62), ('ValutaNews', 1), ('Digital', 1), ('Tech', 7), ('Cloud' ...

# %%
#Set up the file to write the hashtags and counts to. Note, parameter newline = '' helps avoid writing blank lines in between  
writefile = open('hashtag_counts.csv','w', newline='')
writer = csv.writer(writefile)

#write the hashtags alsong with corresponding count to a csv file "hashtag_counts.csv"
for key, count in hashtagCounterDict.items():
    writer.writerow([key, count])    

#Make sure to close your file to guarantee it gets flushed
writefile.close()
